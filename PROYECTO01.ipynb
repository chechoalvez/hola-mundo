# %% [markdown]
# <a href="https://colab.research.google.com/github/chechoalvez/hola-mundo/blob/master/PROYECTO01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
proyecto=input("escriba la descripcion del proyecto: ")
Horas_estimadas=input("Escribir las horas estimadas para el proyecto: ")
Valor_hora=input("¿cual es el valor de la hora trabajada?: ")
Plazo_estimado=input("Escriba cuanto tiempo estima para este proyecto: ")
print(proyecto)
print(Horas_estimadas)
print(Valor_hora)
print(Plazo_estimado)
# Out:
# escriba la descripcion del proyecto: analisis financiero
# Escribir las horas estimadas para el proyecto: 20
# ¿cual es el valor de la hora trabajada?: 20
# Escriba cuanto tiempo estima para este proyecto: 2meses
# analisis financiero
# 20
# 20
# 2meses

# %%
print(10 + 12)
print(122-22)
print(11*4)
print(10/2)
# Out:
# 22
# 100
# 44
# 5.0

# %% [markdown]
# ## Calculando el valor total del proyecto

# %%
valor_total = (int(Horas_estimadas) * int(Valor_hora))
print(valor_total)
# Out:
# 400
